# %%
import json

# %%
with open("result_cxr/filtered_long_dict.json", "r") as f:
    data = json.load(f)

# %%
new_data = {}
for key, value in data.items():
    if len(value) >= 5:
        new_data[key] = value
    else: continue

# %%
with open("./result_cxr/cxrv2.txt", "r") as f:
    for key, value in new_data.itesm():
        for i in value:
# Out:
# dict_keys(['pe', 'cs', 'hs', 'la', 'ar', 'bpe', 'ps', 'mr', 'ap', 'ms', 'bc', 'nl', 'sh', 'ra', 'rl', 'nt', 'cp', 'ch', 'et', 'rs', 'pr', 'll', 'hc', 'fe', 'af', 'pl', 'lv', 'fm', 'bp', 'hd', 'as', 'ba', 'rd', 'uc', 'tf', 'fc', 'il', 'rf', 'lpe', 'sa', 'mc', 'lb', 'bb', 'sc', 'mpe', 'cc', 'rc', 'ce', 'rv', 'sp', 'pt', 'mv', 'fa', 'vc', 'me', 'mp', 'rb', 'ip', 'pv', 'pa', 'sd', 'sf', 'ro', 'sr', 'ns', 'os', 'lo', 'tt', 'hr', 'bo', 'lc', 'or', 'st', 'up', 'hf', 'mf', 'ca', 'ii', 'rh', 'cd', 'pf', 'spe', 'aa', 'wc', 'ue', 'dc', 'lh', 'cf', 'im', 'if', 'nc', 'ic', 'ls', 'dd', 'ie', 'sb', 'ul', 'vs', 'id', 'cl', 'fd', 'ph', 'lp', 'bs', 'pp', 'ci', 'lg', 'pc', 'ts', 'is', 'tl', 'ab', 'ct', 'ape', 'bh', 'ec', 'md', 'pi', 'vt', 'ld', 'es', 'po', 'sw', 'ih', 'so', 'cr', 'ad', 'td', 'se', 'ai', 'de', 'lf', 'ua', 'fr', 'hm', 'ti', 'ri', 'fi', 'ia', 'iv', 're', 'ag', 'be', 'dt', 'ma', 'le', 'li', 'rm', 'si', 'bi', 'sl', 'ir', 'dp', 'ae', 'gs', 'nd', 'ds', 'ac', 'ne', 'cm', 'fw', 'hh', 'nr', 'us', 'rr', 'fs', 'ru', 'al', 'pn', 'ss', 'gc', 'hl', 'rp', 'fp', 'na', 'io', 'ft', 'mm', 'iw', 'co', 'oc', 'vd', 'gi', 'pd', 'el', 'psc', 'fl', 'fb', 'psh', 'rt', 'tp', 'an', 'mi', 'at', 'sv', 'bv', 'he', 'tv', 'bl', 'dr', 'ah', 'dl', 'ho', 'nf', 'ln', 'ni', 'gd', 'lm', 'no', 'pm', 'bg', 'nm', 'op', 'hp', 'it', 'ao', 'df', 'bm', 'ed', 'tc', 'lr', 'ml', 'mb', 'ot', 'of', 'mh', 'vr', 'ib', 'db', 'mt', 'ea', 'aw', 'np', 'er', 'bpo', 'bt', 'sm', 'oe', 'oa', 'ef', 'ha', 'lt', 'oi', 'pap', 'bd', 'ei', 'vp', 'om', 'da', 'do', 'te', 'rcc'])

# %%
# Out:
# ['improved aeration',
#  'iv antibiotics',
#  'icu admission',
#  'interstitial abnormality',
#  'initial abg',
#  'iv abx',
#  'inferior aspect',
#  'iv access',
#  'indeterminate age',
#  'interval appearance',
#  'iv ativan',
#  'inferolateral akinesis']
