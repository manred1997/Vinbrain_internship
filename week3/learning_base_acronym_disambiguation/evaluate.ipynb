# %%
import json

# %%
with open("../AAAI-21-SDU-shared-task-2-AD/dataset/dev.json", "r") as f:
    dev =  json.load(f)
with open("../AAAI-21-SDU-shared-task-2-AD/dataset/diction.json", "r") as f:
    diction =json.load(f)

# %%
dev[0]
# Out:
# {'acronym': 5,
#  'expansion': 'federated learning',
#  'id': 'DEV-0',
#  'tokens': ['In',
#   ',',
#   'we',
#   'investigated',
#   'the',
#   'FL',
#   'loss',
#   'function',
#   'minimization',
#   'problem',
#   'with',
#   'taking',
#   'into',
#   'account',
#   'packet',
#   'errors',
#   'over',
#   'wireless',
#   'links',
#   '.']}
