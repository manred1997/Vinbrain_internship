# %%
import json

# %%
with open("../AAAI-21-SDU-shared-task-2-AD/dataset/dev.json", "r") as f:
    gold = dict([(d['id'], d['expansion']) for d in json.load(f)])

# %%
with open("../AAAI-21-SDU-shared-task-2-AD/dataset/predictions.json", "r") as f:
    pred = dict([(d['id'], d['prediction']) for d in json.load(f)])

# %%
gold
# Out:
# {'DEV-0': 'federated learning',
#  'DEV-1': 'random forest',
#  'DEV-2': 'convolutional neural network',
#  'DEV-3': 'differential evolution',
#  'DEV-4': 'radio frequency',
#  'DEV-5': 'louisiana state university',
#  'DEV-6': 'computed tomography',
#  'DEV-7': 'convolutional neural network',
#  'DEV-8': 'recurrent neural network',
#  'DEV-9': 'regression function',
#  'DEV-10': 'adjacent channel interference',
#  'DEV-11': 'convolutional neural network',
#  'DEV-12': 'reinforcement learning',
#  'DEV-13': 'constructive interference',
#  'DEV-14': 'context entities',
#  'DEV-15': 'threshold algorithm',
#  'DEV-16': 'long term evolution',
#  'DEV-17': 'information embedding cost',
#  'DEV-18': 'mutual information',
#  'DEV-19': 'deep context prediction',
#  'DEV-20': 'convolutional neural network',
#  'DEV-21': 'semantic role labeling',
#  'DEV-22': 'average precision',
#  'DEV-23': 'deep convolutional neural network',
#  'DEV-24': 'town crier',
#  'DEV-25': 'resilience vector',
# ...

# %%
pred = [pred[k] for k,v in gold.items()]
gold = [gold[k] for k,v in gold.items()]

# %%
# Out:
# ['federated learning',
#  'random forest',
#  'convolutional neural network',
#  'differential evolution',
#  'radio frequency',
#  'louisiana state university',
#  'computed tomography',
#  'convolutional neural network',
#  'recurrent neural network',
#  'regression function',
#  'adjacent channel interference',
#  'convolutional neural network',
#  'reinforcement learning',
#  'constructive interference',
#  'context entities',
#  'threshold algorithm',
#  'long term evolution',
#  'information embedding cost',
#  'mutual information',
#  'deep context prediction',
#  'convolutional neural network',
#  'semantic role labeling',
#  'average precision',
#  'deep convolutional neural network',
#  'town crier',
#  'resilience vector',
#  'dogleg',
#  'artificial noise',
#  'linear discriminant analysis',
#  'convolutional neural network',
#  'fixed point',
#  'minimum generation error',
#  'best alignment metric',
#  'model predictive control',
#  'mean squared error',
# ...

# %%
len(gold)
# Out:
# 6189

# %%
len(pred)
# Out:
# 6189

# %%
pred[0] == gold[0]
# Out:
# True

# %%
expansions = set()

# %%
expansions
# Out:
# set()

# %%
from collections import defaultdict

# %%
correct_per_expansion = defaultdict(int)
total_per_expansion = defaultdict(int)
pred_per_expansion = defaultdict(int)

# %%
correct_per_expansion
# Out:
# defaultdict(int, {})

# %%
expansions.add(gold[0])

# %%
expansions
# Out:
# {'federated learning'}

# %%
total_per_expansion[gold[0]] += 1

# %%
total_per_expansion
# Out:
# defaultdict(int, {'federated learning': 1})

# %%
pred_per_expansion[pred[0]] += 1

# %%
pred_per_expansion
# Out:
# defaultdict(int, {'federated learning': 1})

# %%
correct_per_expansion[gold[0]] += 1

# %%
precs = defaultdict(int)
recalls = defaultdict(int)
